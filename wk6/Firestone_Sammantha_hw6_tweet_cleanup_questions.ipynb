# %% [markdown]
# # Pandas DataFrame for storing tweet feed (total 12 points)
#
# Creating the following date frame for storing tweets:
#
# - **climate_feed_df** DataFrame for storing tweets
# - **retweeted_status_df** for storing original tweets

# %%
import pandas as pd
import numpy as np
import nltk
import re
import requests
from bs4 import BeautifulSoup as bsp

# %% [markdown]
# The pickle files retweeted_status_df.pkl and climate_feed.pkl should be in the same folder as this notebook.
# If needed, they can also be downloaded by uncommenting the commands below.  There are csv files of these posted on 2DU under the files section if you are unable to read the pkl files.

# %%
# !wget https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl
# Out:
# --2022-10-23 10:13:03--  https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/psnegi/data_science_tools1/master/hws/retweeted_status_df.pkl [following]
# --2022-10-23 10:13:03--  https://raw.githubusercontent.com/psnegi/data_science_tools1/master/hws/retweeted_status_df.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13793850 (13M) [application/octet-stream]
# Saving to: ‘retweeted_status_df.pkl.3’
#
# retweeted_status_df 100%[===================>]  13.15M  20.5MB/s    in 0.6s
#
# 2022-10-23 10:13:04 (20.5 MB/s) - ‘retweeted_status_df.pkl.3’ saved [13793850/13793850]

# %%
# !wget https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl
# Out:
# --2022-10-23 10:13:04--  https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/psnegi/data_science_tools1/master/hws/climate_feed.pkl [following]
# --2022-10-23 10:13:05--  https://raw.githubusercontent.com/psnegi/data_science_tools1/master/hws/climate_feed.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9122192 (8.7M) [application/octet-stream]
# Saving to: ‘climate_feed.pkl.5’
#
# climate_feed.pkl.5  100%[===================>]   8.70M  19.2MB/s    in 0.5s
#
# 2022-10-23 10:13:06 (19.2 MB/s) - ‘climate_feed.pkl.5’ saved [9122192/9122192]

# %% [markdown]
# <font color= "red">Click on these links if the above downloads fail. </font>
#
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl
#
# Keep these pickle files in the same directory as the notebook

# %%
retweeted_status_df = pd.read_pickle("./retweeted_status_df.pkl")

# %%
retweeted_status_df
# Out:
#       contributors coordinates                      created_at  \
# 0              NaN         NaN                             NaN
# 1              NaN        None  Sat Feb 09 20:27:45 +0000 2019
# 2              NaN        None  Sat Feb 09 23:56:18 +0000 2019
# 3              NaN        None  Sat Feb 09 23:34:27 +0000 2019
# 4              NaN        None  Sat Feb 09 19:07:56 +0000 2019
# ...            ...         ...                             ...
# 9994           NaN        None  Sat Feb 09 20:56:39 +0000 2019
# 9995           NaN        None  Thu Feb 07 20:27:55 +0000 2019
# 9996           NaN        None  Sat Feb 09 18:33:00 +0000 2019
# 9997           NaN        None  Fri Feb 08 22:15:50 +0000 2019
# 9998           NaN        None  Sat Feb 09 20:41:00 +0000 2019
#
#                                                entities extended_entities  \
# 0                                                   NaN               NaN
# 1     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
#
#       favorite_count favorited   geo            id               id_str  ...  \
# 0                NaN       NaN   NaN           NaN                  NaN  ...
# 1               99.0     False  None  1.094332e+18  1094332044052549633  ...
# 2                6.0     False  None  1.094385e+18  1094384528267902977  ...
# 3              190.0     False  None  1.094379e+18  1094379028608438272  ...
# 4             2905.0     False  None  1.094312e+18  1094311957669265408  ...
# ...              ...       ...   ...           ...                  ...  ...
# 9994             1.0     False  None  1.094339e+18  1094339317324017665  ...
# 9995          3491.0     False  None  1.093607e+18  1093607309606076416  ...
# 9996         12586.0     False  None  1.094303e+18  1094303164805799936  ...
# 9997          4249.0     False  None  1.093997e+18  1093996855111966720  ...
# 9998           166.0     False  None  1.094335e+18  1094335377194799104  ...
#
#                                           quoted_status  quoted_status_id  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2     {'favorited': False, 'favorite_count': 2642, '...      1.093999e+18
# 3     {'favorited': False, 'favorite_count': 220, 'i...      1.093932e+18
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 9994                                                NaN               NaN
# 9995                                                NaN               NaN
# 9996                                                NaN               NaN
# 9997  {'favorited': False, 'favorite_count': 551, 'i...      1.093893e+18
# 9998                                                NaN               NaN
#
#      quoted_status_id_str  retweet_count retweeted scopes  \
# 0                     NaN            NaN       NaN    NaN
# 1                     NaN           81.0     False    NaN
# 2     1093998640392220673            5.0     False    NaN
# 3     1093931686998487040           31.0     False    NaN
# 4                     NaN          599.0     False    NaN
# ...                   ...            ...       ...    ...
# 9994                  NaN            1.0     False    NaN
# 9995                  NaN          482.0     False    NaN
# 9996                  NaN         2801.0     False    NaN
# 9997  1093893115633647616          642.0     False    NaN
# 9998                  NaN           79.0     False    NaN
#
#                                                  source  \
# 0                                                   NaN
# 1     <a href="http://twitter.com" rel="nofollow">Tw...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/android" ...
# 9996  <a href="https://about.twitter.com/products/tw...
# 9997  <a href="https://mobile.twitter.com" rel="nofo...
# 9998  <a href="https://buffer.com" rel="nofollow">Bu...
#
#                                                    text truncated  \
# 0                                                   NaN       NaN
# 1     The National Party declares war on the Glouces...      True
# 2     This is the same idiot who thought\nThe southe...     False
# 3     Communism is Fascism. Fighting Climate Change ...      True
# 4     Unmitigated climate change would literally des...      True
# ...                                                 ...       ...
# 9994  72% of Americans are 'very worried' about clim...     False
# 9995  @JFaurall @MgBenchjeweler @SpeakerPelosi Calif...      True
# 9996  President Trump believes we should listen to f...      True
# 9997  Wait til he hears how much climate change is g...     False
# 9998       Blue marble no more? https://t.co/hFLndZsiBB     False
#
#                                                    user
# 0                                                   NaN
# 1     {'default_profile': False, 'protected': False,...
# 2     {'default_profile': False, 'protected': False,...
# 3     {'default_profile': False, 'protected': False,...
# 4     {'default_profile': True, 'protected': False, ...
# ...                                                 ...
# 9994  {'default_profile': True, 'protected': False, ...
# 9995  {'default_profile': True, 'protected': False, ...
# 9996  {'default_profile': False, 'protected': False,...
# 9997  {'default_profile': False, 'protected': False,...
# 9998  {'default_profile': False, 'protected': False,...
#
# [9999 rows x 30 columns]

# %%
#climate_feed_df.to_pickle("./climate_feed.pkl")
climate_feed_df = pd.read_pickle("./climate_feed.pkl")

# %%
climate_feed_df
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Sun Feb 10 00:17:31 +0000 2019
# 1            None        None  Sun Feb 10 00:17:30 +0000 2019
# 2            None        None  Sun Feb 10 00:17:26 +0000 2019
# 3            None        None  Sun Feb 10 00:17:24 +0000 2019
# 4            None        None  Sun Feb 10 00:17:23 +0000 2019
# ...           ...         ...                             ...
# 9994         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9995         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9996         None        None  Sat Feb 09 20:57:53 +0000 2019
# 9997         None        None  Sat Feb 09 20:57:51 +0000 2019
# 9998         None        None  Sat Feb 09 20:57:51 +0000 2019
#
#                                                entities extended_entities  \
# 0     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
#
#      favorite_count favorited   geo                   id               id_str  \
# 0                 0     False  None  1094389867499405313  1094389867499405313
# 1                 0     False  None  1094389862193455105  1094389862193455105
# 2                 0     False  None  1094389844078485506  1094389844078485506
# 3                 0     False  None  1094389837522599936  1094389837522599936
# 4                 0     False  None  1094389831419994112  1094389831419994112
# ...             ...       ...   ...                  ...                  ...
# 9994              0     False  None  1094339630500012033  1094339630500012033
# 9995              0     False  None  1094339629107400704  1094339629107400704
# 9996              0     False  None  1094339627316641794  1094339627316641794
# 9997              0     False  None  1094339619569557504  1094339619569557504
# 9998              0     False  None  1094339617581481984  1094339617581481984
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 0     ...           NaN                  NaN                  NaN
# 1     ...           NaN                  NaN                  NaN
# 2     ...           NaN  1093998640392220673  1093998640392220673
# 3     ...           NaN  1093931686998487040  1093931686998487040
# 4     ...           NaN                  NaN                  NaN
# ...   ...           ...                  ...                  ...
# 9994  ...           NaN                  NaN                  NaN
# 9995  ...           NaN                  NaN                  NaN
# 9996  ...           NaN                  NaN                  NaN
# 9997  ...           NaN  1093893115633647616  1093893115633647616
# 9998  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 0                0     False              NaN
# 1               81     False     1.094332e+18
# 2                5     False     1.094385e+18
# 3               31     False     1.094379e+18
# 4              599     False     1.094312e+18
# ...            ...       ...              ...
# 9994             1     False     1.094339e+18
# 9995           482     False     1.093607e+18
# 9996          2801     False     1.094303e+18
# 9997           642     False     1.093997e+18
# 9998            79     False     1.094335e+18
#
#                                                  source  \
# 0     <a href="http://twitter.com" rel="nofollow">Tw...
# 1     <a href="http://tapbots.com/tweetbot" rel="nof...
# 2     <a href="https://mobile.twitter.com" rel="nofo...
# 3     <a href="http://twitter.com" rel="nofollow">Tw...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/iphone" r...
# 9996  <a href="http://twitter.com/download/android" ...
# 9997  <a href="http://twitter.com/download/iphone" r...
# 9998  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text truncated  \
# 0     .@SteveKingIA says he's unsure about the scien...      True
# 1     RT @RobOakeshott1: The National Party declares...     False
# 2     RT @emilia_suze: This is the same idiot who th...     False
# 3     RT @PrettyBadLefty: Communism is Fascism. Figh...     False
# 4     RT @kenklippenstein: Unmitigated climate chang...     False
# ...                                                 ...       ...
# 9994  RT @fromhello2hello: 72% of Americans are 'ver...     False
# 9995  RT @stuntdaddy_42: @JFaurall @MgBenchjeweler @...     False
# 9996  RT @SenSanders: President Trump believes we sh...     False
# 9997  RT @KateAronoff: Wait til he hears how much cl...     False
# 9998  RT @GeorgeTakei: Blue marble no more? https://...     False
#
#                   user_id
# 0                31476142
# 1               996782298
# 2                45333453
# 3     1020067726532829185
# 4                19889325
# ...                   ...
# 9994   888112320097918976
# 9995           3324836714
# 9996           1487109794
# 9997           4737089913
# 9998             19444003
#
# [9999 rows x 30 columns]

# %% [markdown]
# Here are dtypes for climate_feed_df. We'll work with only
# - entities to extract hashtags
# - retweeted_status in case we need to extract original full tweet
# - truncated
# - text: tweet text
# - created_at
# - user_id
#
# Some of them have wrong datatypes.

# %%
climate_feed_df.dtypes
# Out:
# contributors                  object
# coordinates                   object
# created_at                    object
# entities                      object
# extended_entities             object
# favorite_count                object
# favorited                     object
# geo                           object
# id                            object
# id_str                        object
# in_reply_to_screen_name       object
# in_reply_to_status_id         object
# in_reply_to_status_id_str     object
# in_reply_to_user_id           object
# in_reply_to_user_id_str       object
# is_quote_status               object
# lang                          object
# metadata                      object
# place                         object
# possibly_sensitive            object
# quoted_status                 object
# quoted_status_id              object
# quoted_status_id_str          object
# retweet_count                 object
# retweeted                     object
# retweeted_status             float64
# source                        object
# text                          object
# truncated                     object
# user_id                        int64
# dtype: object

# %% [markdown]
# # Q1 (0.5 point) Replace None with nan in climate_feed_df. Also display some random rows.

# %%
climate_feed_df = climate_feed_df.replace('None', 'NaN')
climate_feed_df.sample(10)
# Out:
#      contributors coordinates                      created_at  \
# 5363          NaN         NaN  Sat Feb 09 22:28:47 +0000 2019
# 3582          NaN         NaN  Sat Feb 09 23:08:09 +0000 2019
# 2262          NaN         NaN  Sat Feb 09 23:34:30 +0000 2019
# 6044          NaN         NaN  Sat Feb 09 22:15:55 +0000 2019
# 2005          NaN         NaN  Sat Feb 09 23:39:12 +0000 2019
# 6692          NaN         NaN  Sat Feb 09 22:02:13 +0000 2019
# 907           NaN         NaN  Sat Feb 09 23:59:40 +0000 2019
# 1141          NaN         NaN  Sat Feb 09 23:55:07 +0000 2019
# 7988          NaN         NaN  Sat Feb 09 21:36:19 +0000 2019
# 8426          NaN         NaN  Sat Feb 09 21:27:20 +0000 2019
#
#                                                entities extended_entities  \
# 5363  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3582  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2262  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 6044  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2005  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 6692  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 907   {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1141  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 7988  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 8426  {'hashtags': [{'indices': [58, 68], 'text': 'T...               NaN
#
#      favorite_count favorited  geo                   id               id_str  \
# 5363              0     False  NaN  1094362500332630016  1094362500332630016
# 3582              1     False  NaN  1094372409413722114  1094372409413722114
# 2262              0     False  NaN  1094379042587979776  1094379042587979776
# 6044              0     False  NaN  1094359262552305664  1094359262552305664
# 2005              0     False  NaN  1094380225159286784  1094380225159286784
# 6692              0     False  NaN  1094355817996959746  1094355817996959746
# 907               0     False  NaN  1094385372325400578  1094385372325400578
# 1141              0     False  NaN  1094384229050449920  1094384229050449920
# 7988              0     False  NaN  1094349297888493568  1094349297888493568
# 8426              1     False  NaN  1094347039528361984  1094347039528361984
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 5363  ...           NaN                  NaN                  NaN
# 3582  ...           NaN                  NaN                  NaN
# 2262  ...           NaN                  NaN                  NaN
# 6044  ...           NaN                  NaN                  NaN
# 2005  ...           NaN                  NaN                  NaN
# 6692  ...           NaN                  NaN                  NaN
# 907   ...           NaN                  NaN                  NaN
# 1141  ...           NaN                  NaN                  NaN
# 7988  ...           NaN  1093871822490218498  1093871822490218498
# 8426  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 5363            49     False     1.094359e+18
# 3582             0     False              NaN
# 2262             7     False     1.094233e+18
# 6044            54     False     1.094253e+18
# 2005            49     False     1.094359e+18
# 6692            13     False     1.094355e+18
# 907              0     False              NaN
# 1141           107     False     1.094376e+18
# 7988            39     False     1.094054e+18
# 8426             0     False              NaN
#
#                                                  source  \
# 5363  <a href="http://twitter.com/download/iphone" r...
# 3582  <a href="http://twitter.com/download/iphone" r...
# 2262  <a href="http://twitter.com/download/android" ...
# 6044  <a href="http://twitter.com/download/iphone" r...
# 2005  <a href="http://twitter.com/download/iphone" r...
# 6692  <a href="https://mobile.twitter.com" rel="nofo...
# 907   <a href="https://mobile.twitter.com" rel="nofo...
# 1141  <a href="http://twitter.com/download/android" ...
# 7988  <a href="http://twitter.com/download/iphone" r...
# 8426  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text truncated  \
# 5363  RT @_Oliver_Yates: If only Abbott could fight ...     False
# 3582  I’ve been watching all th we documentaries on ...      True
# 2262  RT @xRebelCanada: Unbelievable. @CBCTheNationa...     False
# 6044  RT @ChrisvandenBos: Er komen steeds meer aanwi...     False
# 2005  RT @_Oliver_Yates: If only Abbott could fight ...     False
# 6692  RT @FiveThirtyEight: How much is the governmen...     False
# 907   @realDonaldTrump You'll get the Irish people t...      True
# 1141  RT @drawandstrike: THIS is why on almost every...     False
# 7988  RT @jerry_jtaylor: Yep—Republican members of t...     False
# 8426  The real challenge is not climate change, but ...     False
#
#                   user_id
# 5363            293834848
# 3582  1036245779176988678
# 2262           3406405169
# 6044            135195591
# 2005           2723055877
# 6692            172954545
# 907              25695193
# 1141   811936350970806273
# 7988             26366836
# 8426           1550477484
#
# [10 rows x 30 columns]

# %% [markdown]
# Working with only selected attributes.

# %%
climate_feed_df = climate_feed_df[['created_at', 'entities','retweeted_status', 'truncated', 'user_id', 'text' ]].copy()

# %%
climate_feed_df.sample(10)
# Out:
#                           created_at  \
# 8287  Sat Feb 09 21:30:18 +0000 2019
# 3630  Sat Feb 09 23:07:04 +0000 2019
# 2085  Sat Feb 09 23:37:32 +0000 2019
# 2506  Sat Feb 09 23:29:52 +0000 2019
# 9489  Sat Feb 09 21:07:39 +0000 2019
# 7515  Sat Feb 09 21:46:10 +0000 2019
# 7807  Sat Feb 09 21:40:30 +0000 2019
# 4742  Sat Feb 09 22:42:07 +0000 2019
# 9357  Sat Feb 09 21:10:01 +0000 2019
# 7868  Sat Feb 09 21:39:11 +0000 2019
#
#                                                entities  retweeted_status  \
# 8287  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094342e+18
# 3630  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094086e+18
# 2085  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094376e+18
# 2506  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9489  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 7515  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 7807  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.093876e+18
# 4742  {'hashtags': [{'indices': [63, 77], 'text': 'c...               NaN
# 9357  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094301e+18
# 7868  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094335e+18
#
#      truncated              user_id  \
# 8287     False           2429615682
# 3630     False             32339623
# 2085     False           1489325107
# 2506     False           2683471818
# 9489      True  1048468329726238720
# 7515      True             18601783
# 7807     False            143947621
# 4742     False            313938680
# 9357     False             17863929
# 7868     False   923930869332660226
#
#                                                    text
# 8287  RT @maxphillips: This goose attacks the judge ...
# 3630  RT @greensjeremy: Johnsen's attitude shows tha...
# 2085  RT @drawandstrike: THIS is why on almost every...
# 2506  @SCH451 @RitaPanahi @SkyNewsAust Climate chang...
# 9489  @JacobAWohl @not2fastman Yup, this is the poin...
# 7515  @DanCrenshawTX Looking forward to the Republic...
# 7807  RT @larrykim: 👏Elon Musk has released all of T...
# 4742  Earth's coldest years on record all happened o...
# 9357  RT @ConversationUK: Banksy's 'boy in falling s...
# 7868  RT @DavidWaddell5: Nikki Haley on Pelosi’s Cal...

# %% [markdown]
# # Q2 (0.5 point) convert
# - created_at to date time type
# - truncated to bool type.

# %%
climate_feed_df['created_at'] = pd.to_datetime(climate_feed_df['created_at'])
climate_feed_df["truncated"] = np.where(climate_feed_df["truncated"] == "True", True, False)

# %% [markdown]
# Checking datatype again

# %%
climate_feed_df.dtypes
# Out:
# created_at          datetime64[ns, UTC]
# entities                         object
# retweeted_status                float64
# truncated                          bool
# user_id                           int64
# text                             object
# dtype: object

# %% [markdown]
# # Q3(1 point) In climate_feed_df, calculate the number of NAN values in various columns

# %%
climate_feed_df.isna().sum().sum()
# Out:
# 2690

# %% [markdown]
# We'll use **ast** module to parse string to python dictionary

# %% [markdown]
# # Q4(3 points) Using *ast* module  convert entities to python dictionary. This dictionary should contain hashtags and user_mentions
#  - Create a column named hashtags. Values in this columns should be comma separated values of **text** attribute in **hashtags**  value.
#  - Create a column named user_mentions. Values in this columns should be command separated values of **name** attribute in **user_mentions** values.

# %%
import ast

climate_feed_df["entities"] = climate_feed_df["entities"].apply(lambda x: ast.literal_eval(x))

# %%
hashes = [k['hashtags'] for k in climate_feed_df["entities"]]
mentions = [k['user_mentions'] for k in climate_feed_df["entities"]]

climate_feed_df['hashtags'] = hashes
climate_feed_df['user_mentions'] = mentions

# %%
for i in range(len(climate_feed_df)):
    hashValues = climate_feed_df.loc[i,'hashtags']
    if hashValues:
        text = []
        for t in hashValues:
            words = t.get('text')
            text.append(words)
            climate_feed_df.at[i,'hashtags'] = ','.join(map(str, text))
    else:
        climate_feed_df.at[i,'hashtags'] = None
        
    users = climate_feed_df.loc[i,'user_mentions']
    if users:
        names = []
        for k in users:
            name = k.get('name')
            names.append(name)
            climate_feed_df.at[i,'user_mentions'] = ','.join(map(str, names))
    else:
        climate_feed_df.at[i,'user_mentions'] = None

climate_feed_df.sample(10)
# Out:
#                     created_at  \
# 591  2019-02-10 00:05:14+00:00
# 2051 2019-02-09 23:38:00+00:00
# 3232 2019-02-09 23:15:24+00:00
# 9825 2019-02-09 21:01:00+00:00
# 8891 2019-02-09 21:18:25+00:00
# 4766 2019-02-09 22:41:24+00:00
# 7300 2019-02-09 21:50:06+00:00
# 3473 2019-02-09 23:10:24+00:00
# 8807 2019-02-09 21:20:05+00:00
# 5914 2019-02-09 22:18:16+00:00
#
#                                                entities  retweeted_status  \
# 591   {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094312e+18
# 2051  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094099e+18
# 3232  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094303e+18
# 9825  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094338e+18
# 8891  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.093742e+18
# 4766  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094212e+18
# 7300  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3473  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 8807  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094303e+18
# 5914  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094212e+18
#
#       truncated              user_id  \
# 591       False  1012838348866478081
# 2051      False           4765356816
# 3232      False            320508151
# 9825      False   967373485839335427
# 8891      False            513496156
# 4766      False           3420837819
# 7300      False           1075435874
# 3473      False            602035691
# 8807      False           2978846170
# 5914      False           2228896081
#
#                                                    text hashtags  \
# 591   RT @kenklippenstein: Unmitigated climate chang...     None
# 2051  RT @UN: Climate change is a race we can win. \...     None
# 3232  RT @SenSanders: President Trump believes we sh...     None
# 9825  RT @PenguinUKBooks: ‘We could look back on the...     None
# 8891  RT @aIecrl: @Rockwood_EDP My immune system and...     None
# 4766  RT @marklevinshow: The insane Democrat Left.  ...     None
# 7300  Harrison Ford warns of apocalyptic catastrophe...     None
# 3473       @Jim_Brunner Isn’t this climate change, tho?     None
# 8807  RT @SenSanders: President Trump believes we sh...     None
# 5914  RT @marklevinshow: The insane Democrat Left.  ...     None
#
#                              user_mentions
# 591                       Ken Klippenstein
# 2051       United Nations,António Guterres
# 3232                        Bernie Sanders
# 9825  Penguin Books UK,David Wallace-Wells
# 8891                     Alec,Ben Rockwood
# 4766                         Mark R. Levin
# 7300                     Daily Mail Online
# 3473                           Jim Brunner
# 8807                        Bernie Sanders
# 5914                         Mark R. Levin

# %% [markdown]
# # Cleaning tweets
#
# Let's see some random tweets

# %%
tweet_length = 280
pd.set_option('max_colwidth', 2*tweet_length)
climate_feed_df['text'].sample(100)
# Out:
# 4579       Would Tony have a climate change conversion to win #WarringahVotes? Wouldn’t put it past him, if dirt fails #auspol https://t.co/aVca0OcbjP
# 2926      @Noahpinion @KeithBKyle @miwayha Oh wait, aren't you that guy who still doesn't see why "just transition" is necess… https://t.co/MU32jM1SIh
# 1610      RT @ida_skibenes: Science/history based education is key to a thriving community. It’s key to end the skepticism around climate change. It’…
# 5412                                                            YES! Climate Change is reality and there's so much we MUST do. https://t.co/XzV7TsLMef
# 6583       RT @EnvDefenseFund: More and more Americans recognize -- and are impacted -- by the effects of climate change. We need rational leadership…
#                                                                              ...
# 9202                                                                     @lamphieryeg Flying to Victoria carbon free next week https://t.co/5iNDXi6bKF
# 450       RT @eugenegu: @realDonaldTrump Trump is underestimating the resolve of the American people when it comes to Climate Change and the Green Ne…
# 8446      RT @Zeddary: Hi everyone the literal plot of Game of Thrones is society paying the ultimate price as squabbling rich guys sabotage each oth…
# 3608    RT @Alex_Verbeek: 🇺🇸 \n\n“Even the solutions that we have considered big and bold are nowhere near the scale of the actual problem that clima…
# 7735      RT @PaulEDawson: “Limited warming to 1.5°C (2.7°F) is possible within the laws of chemistry and physics, but doing so would require unprece…
# Name: text, Length: 100, dtype: object

# %% [markdown]
# **Example of tweet not truncated**

# %%
climate_feed_df['text'].loc[3929]
# Out:
# 'Fighting climate change without nuclear is a fool’s errand. https://t.co/KPSCk6fjsa'

# %% [markdown]
# **Exampe of tweet truncated**

# %%
climate_feed_df['text'].loc[3928]
# Out:
# 'RT @_Oliver_Yates: If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fighting f…'

# %% [markdown]
# Truncated tweet has three horizontal ellipses in it. One can check retweeted_status values and
# use it got the the original tweet text

# %%
climate_feed_df.retweeted_status.loc[3928]
# Out:
# 1.0943594112863928e+18

# %%
retweeted_status_df[retweeted_status_df.id == climate_feed_df.retweeted_status.loc[3928]].text.iloc[0]
# Out:
# 'If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fight… https://t.co/OJlsDeFoNA'

# %% [markdown]
# There is url above tweet. We can use **requests** to get the complete text.

# %% [markdown]
# # Q5(3 points) Perform following activities for creating a new original_tweet_text field in climate_feed_df.
#
# If a record from climate_feed_df has a valid **retweeted_status** value (i.e., it's not null) then search for the original text in retweeted_status_df **text** column.  The text of the tweet in retweeted_status_df will have a url.  This is the url for the original tweet.  On the other hand, if the **truncated** value in climate_feed_df is True, then the record won't have a valid retweet id (it's not a retweet) and the **text** value in climate_feed_df will contain the link to the original tweet.
#
# Search for the original text in retweeted_status_df for tweets with a valid **retweeted_status**.  Store this value in a new column in climate_feed_df called **final_tweet_text**.  I there is not a valid **retweeted_status** in climate_feed_df, then use the value from the **text** column in climate_feed_df.
#
# Finally, create the field **original_tweet_link** in climate_feed_df.  This will be the link to the original tweet which can be obtained from the text field in retweeted_status_df.
#
# Note that we could then use the URLs to retrieve the full tweet text.  This was the requirement of the original assignmnet.  We won't do anything with the URLs except practice extracting them.

# %%
import numpy 

for i in range(len(climate_feed_df)):
    retweet = climate_feed_df.loc[i]['retweeted_status']
    if ~numpy.isnan(retweet):
        climate_feed_df.at[i,'final_tweet_text'] = retweeted_status_df[retweeted_status_df.id == climate_feed_df.retweeted_status.loc[i]].text.iloc[0]
        text = climate_feed_df.at[i, 'final_tweet_text']
        climate_feed_df.at[i, 'original_tweet_link'] = re.findall(r'(https?://\S+)', text)
    else:
        climate_feed_df.at[i,'final_tweet_text'] = climate_feed_df.at[i,'text']
    

climate_feed_df.sample(10)
# Out:
#                     created_at  \
# 4793 2019-02-09 22:40:49+00:00
# 9187 2019-02-09 21:12:52+00:00
# 8570 2019-02-09 21:24:49+00:00
# 3451 2019-02-09 23:11:08+00:00
# 240  2019-02-10 00:12:23+00:00
# 6240 2019-02-09 22:11:34+00:00
# 1634 2019-02-09 23:46:00+00:00
# 6424 2019-02-09 22:07:40+00:00
# 27   2019-02-10 00:16:57+00:00
# 4910 2019-02-09 22:38:31+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                     entities  \
# 4793                                                                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '29442313', 'name': 'Bernie Sanders', 'screen_name': 'SenSanders', 'indices': [3, 14], 'id': 29442313}], 'urls': [], 'symbols': []}
# 9187                                                                                                                                                                                                                                                   {'hashtags': [], 'user_mentions': [{'id_str': '870452296265605121', 'name': 'Jeffery Wells', 'screen_name': 'jeffery1946', 'indices': [3, 15], 'id': 870452296265605121}], 'urls': [], 'symbols': []}
# 8570                                                                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '189376144', 'name': 'Naomi Klein', 'screen_name': 'NaomiAKlein', 'indices': [3, 15], 'id': 189376144}], 'urls': [], 'symbols': []}
# 3451                                                                                                                                                                                                                                                                      {'hashtags': [], 'user_mentions': [{'id_str': '33537967', 'name': 'Amy Klobuchar', 'screen_name': 'amyklobuchar', 'indices': [3, 16], 'id': 33537967}], 'urls': [], 'symbols': []}
# 240                                                                                                                                                                                                                                                             {'hashtags': [], 'user_mentions': [{'id_str': '499154896', 'name': 'Alexander Bruesewitz', 'screen_name': 'alexanderbruz', 'indices': [3, 17], 'id': 499154896}], 'urls': [], 'symbols': []}
# 6240                                                                                                                                                           {'hashtags': [{'indices': [31, 45], 'text': 'ClimateChange'}], 'user_mentions': [], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/XxS11MWwN1', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094358169139232768'}], 'symbols': []}
# 1634                                                                                                                                                                                                                                                            {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
# 6424  {'hashtags': [], 'user_mentions': [{'id_str': '361919460', 'name': 'David Walsh', 'screen_name': 'DavidAstinWalsh', 'indices': [3, 19], 'id': 361919460}, {'id_str': '846507172435517442', 'name': 'Alex Jay Brady', 'screen_name': 'AlexJayBrady', 'indices': [21, 34], 'id': 846507172435517442}, {'id_str': '634734888', 'name': 'Parker Molloy', 'screen_name': 'ParkerMolloy', 'indices': [35, 48], 'id': 634734888}], 'urls': [], 'symbols': []}
# 27                                                                                                                                                                                                                                                                    {'hashtags': [], 'user_mentions': [{'id_str': '90748205', 'name': 'Pavlina R Tcherneva', 'screen_name': 'ptcherneva', 'indices': [3, 14], 'id': 90748205}], 'urls': [], 'symbols': []}
# 4910                                                       {'hashtags': [], 'user_mentions': [{'id_str': '1094202113117339648', 'name': 'Anna Taylor', 'screen_name': 'AnnaUKSCN', 'indices': [3, 13], 'id': 1094202113117339648}], 'urls': [{'indices': [100, 123], 'url': 'https://t.co/Gc9pZunJQP', 'display_url': 'tes.com/news/meet-uk-p…', 'expanded_url': 'https://www.tes.com/news/meet-uk-pupils-striking-against-climate-change'}], 'symbols': []}
#
#       retweeted_status  truncated             user_id  \
# 4793      1.094303e+18      False  897869176571928576
# 9187      1.094039e+18      False           304356334
# 8570      1.093117e+18      False          3197149114
# 3451      1.092111e+18      False  918835005304004609
# 240       1.094276e+18      False          2868160203
# 6240               NaN       True  958192618940252160
# 1634      1.094312e+18      False          3240868863
# 6424      1.094243e+18      False           527424042
# 27        1.094343e+18      False          2500036429
# 4910      1.094215e+18      False           136059181
#
#                                                                                                                                                   text  \
# 4793    RT @SenSanders: President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9187       RT @jeffery1946: I grew up in Nelson in the 50s and recall that the occasional bush or grass fire rarely spread very far - and long before…
# 8570      RT @NaomiAKlein: People claim Trump said not one word about climate change but that's false. He celebrated the US being the world's "No. 1"…
# 3451      RT @amyklobuchar: Minnesota is home to some of the most incredible forests in the country. New studies report that if we do nothing to slow…
# 240                                 RT @alexanderbruz: Happy Saturday! Friendly reminder that climate change is a hoax! \n\nHave a great day everyone!
# 6240  Harrison Ford is worried about #ClimateChange. \n\nHe has a collection of private planes, cars, helicopters. \n\nI hope… https://t.co/XxS11MWwN1
# 1634      RT @kenklippenstein: Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# 6424       RT @DavidAstinWalsh: @AlexJayBrady @ParkerMolloy The moment someone brings up thermodynamics in the context of climate change, it tells me…
# 27        RT @ptcherneva: Exactly, because orthoodoxy has failed again and again. We can't fight climate change with a carbon tax, just like we didn'…
# 4910                      RT @AnnaUKSCN: Read this TES article for more reasons on why you should strike with us next Friday.\nhttps://t.co/Gc9pZunJQP
#
#            hashtags                             user_mentions  \
# 4793           None                            Bernie Sanders
# 9187           None                             Jeffery Wells
# 8570           None                               Naomi Klein
# 3451           None                             Amy Klobuchar
# 240            None                      Alexander Bruesewitz
# 6240  ClimateChange                                      None
# 1634           None                          Ken Klippenstein
# 6424           None  David Walsh,Alex Jay Brady,Parker Molloy
# 27             None                       Pavlina R Tcherneva
# 4910           None                               Anna Taylor
#
#                                                                                                                                       final_tweet_text  \
# 4793    President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we shoul… https://t.co/2ewlaPQscF
# 9187       I grew up in Nelson in the 50s and recall that the occasional bush or grass fire rarely spread very far - and long… https://t.co/i1xDPNP4qM
# 8570       People claim Trump said not one word about climate change but that's false. He celebrated the US being the world's… https://t.co/w9y9VXre6D
# 3451      Minnesota is home to some of the most incredible forests in the country. New studies report that if we do nothing t… https://t.co/8Cf9scsjxd
# 240                                                    Happy Saturday! Friendly reminder that climate change is a hoax! \n\nHave a great day everyone!
# 6240  Harrison Ford is worried about #ClimateChange. \n\nHe has a collection of private planes, cars, helicopters. \n\nI hope… https://t.co/XxS11MWwN1
# 1634      Unmitigated climate change would literally destroy civilization but doing something about it might increase the def… https://t.co/1J7lLUkYyY
# 6424       @AlexJayBrady @ParkerMolloy The moment someone brings up thermodynamics in the context of climate change, it tells me they’re full of shit.
# 27         Exactly, because orthoodoxy has failed again and again. We can't fight climate change with a carbon tax, just like… https://t.co/Iet0ZBKX99
# 4910                                     Read this TES article for more reasons on why you should strike with us next Friday.\nhttps://t.co/Gc9pZunJQP
#
#             original_tweet_link
# 4793  [https://t.co/2ewlaPQscF]
# 9187  [https://t.co/i1xDPNP4qM]
# 8570  [https://t.co/w9y9VXre6D]
# 3451  [https://t.co/8Cf9scsjxd]
# 240                          []
# 6240                        NaN
# 1634  [https://t.co/1J7lLUkYyY]
# 6424                         []
# 27    [https://t.co/Iet0ZBKX99]
# 4910  [https://t.co/Gc9pZunJQP]

# %% [markdown]
# # Q 6(2 points) Remove all the references  of RT and  @user: or @user, and url in climate_feed_df text attribute.

# %%
for i in range(len(climate_feed_df)):
    text = climate_feed_df['text'][i]
    a = re.sub(r'http\S+|RT|@\S+', '', text)
    climate_feed_df.at[i, 'text'] = a

climate_feed_df
# Out:
#                     created_at  \
# 0    2019-02-10 00:17:31+00:00
# 1    2019-02-10 00:17:30+00:00
# 2    2019-02-10 00:17:26+00:00
# 3    2019-02-10 00:17:24+00:00
# 4    2019-02-10 00:17:23+00:00
# ...                        ...
# 9994 2019-02-09 20:57:54+00:00
# 9995 2019-02-09 20:57:54+00:00
# 9996 2019-02-09 20:57:53+00:00
# 9997 2019-02-09 20:57:51+00:00
# 9998 2019-02-09 20:57:51+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities  \
# 0                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                                                                                                                                                                                                            {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                                                                                                                                                                                                        {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9994                                                                                                                                      {'hashtags': [], 'user_mentions': [{'id_str': '1073261955216039937', 'name': 'fromhello2hello', 'screen_name': 'fromhello2hello', 'indices': [3, 19], 'id': 1073261955216039937}], 'urls': [{'indices': [78, 101], 'url': 'https://t.co/P1X5jfuUQC', 'display_url': 'treehugger.com/climate-change…', 'expanded_url': 'https://www.treehugger.com/climate-change/72-americans-are-very-worried-about-climate-change.html'}], 'symbols': []}
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': '1082006962995429383', 'name': 'stuntdaddy_42', 'screen_name': 'stuntdaddy_42', 'indices': [3, 17], 'id': 1082006962995429383}, {'id_str': '2497547378', 'name': 'Justice Faurall', 'screen_name': 'JFaurall', 'indices': [19, 28], 'id': 2497547378}, {'id_str': '3073664870', 'name': 'Michael Shelton', 'screen_name': 'MgBenchjeweler', 'indices': [29, 44], 'id': 3073664870}, {'id_str': '15764644', 'name': 'Nancy Pelosi', 'screen_name': 'SpeakerPelosi', 'indices': [45, 59], 'id': 15764644}], 'urls': [], 'symbols...
# 9996                                                                                                                                                                                                                                                                                                                                                                                                {'hashtags': [], 'user_mentions': [{'id_str': '29442313', 'name': 'Bernie Sanders', 'screen_name': 'SenSanders', 'indices': [3, 14], 'id': 29442313}], 'urls': [], 'symbols': []}
# 9997                                                                                                                                                                                                               {'hashtags': [], 'user_mentions': [{'id_str': '637196658', 'name': 'Kate Aronoff', 'screen_name': 'KateAronoff', 'indices': [3, 15], 'id': 637196658}], 'urls': [{'indices': [73, 96], 'url': 'https://t.co/P6znQNsbLH', 'display_url': 'twitter.com/business/statu…', 'expanded_url': 'https://twitter.com/business/status/1093893115633647616'}], 'symbols': []}
# 9998                                                                                                                                                                                                                                                                  {'hashtags': [], 'user_mentions': [{'id_str': '237845487', 'name': 'George Takei', 'screen_name': 'GeorgeTakei', 'indices': [3, 15], 'id': 237845487}], 'urls': [{'indices': [38, 61], 'url': 'https://t.co/hFLndZsiBB', 'display_url': 'po.st/P5AgAW', 'expanded_url': 'http://po.st/P5AgAW'}], 'symbols': []}
#
#       retweeted_status  truncated              user_id  \
# 0                  NaN       True             31476142
# 1         1.094332e+18      False            996782298
# 2         1.094385e+18      False             45333453
# 3         1.094379e+18      False  1020067726532829185
# 4         1.094312e+18      False             19889325
# ...                ...        ...                  ...
# 9994      1.094339e+18      False   888112320097918976
# 9995      1.093607e+18      False           3324836714
# 9996      1.094303e+18      False           1487109794
# 9997      1.093997e+18      False           4737089913
# 9998      1.094335e+18      False             19444003
#
#                                                                                                                                   text  \
# 0                            . says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac…
# 1             The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                                            This is the same idiot who thought\nThe southern Alberta chinook was climate change lol.
# 3             Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4              Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# ...                                                                                                                                ...
# 9994                                                                         72% of Americans are 'very worried' about climate change
# 9995                                                   California was given hundreds of millions of dollars over the years to prevent…
# 9996    President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9997                                                                          Wait til he hears how much climate change is gonna cost
# 9998                                                                                                             Blue marble no more?
#
#      hashtags                                               user_mentions  \
# 0        None                                                  Steve King
# 1        None                                               Rob Oakeshott
# 2        None                                              Suze Michelini
# 3        None                                               Chad Vigorous
# 4        None                                            Ken Klippenstein
# ...       ...                                                         ...
# 9994     None                                             fromhello2hello
# 9995     None  stuntdaddy_42,Justice Faurall,Michael Shelton,Nancy Pelosi
# 9996     None                                              Bernie Sanders
# 9997     None                                                Kate Aronoff
# 9998     None                                                George Takei
#
#                                                                                                                                     final_tweet_text  \
# 0       .@SteveKingIA says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac… https://t.co/J1CcrQZkB2
# 1       The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,… https://t.co/G0PqMIEUMV
# 2                                   This is the same idiot who thought\nThe southern Alberta chinook was climate change lol. https://t.co/HWjCJGhQIx
# 3       Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS… https://t.co/2asxrk5Fqd
# 4       Unmitigated climate change would literally destroy civilization but doing something about it might increase the def… https://t.co/1J7lLUkYyY
# ...                                                                                                                                              ...
# 9994                                                                72% of Americans are 'very worried' about climate change https://t.co/P1X5jfuUQC
# 9995    @JFaurall @MgBenchjeweler @SpeakerPelosi California was given hundreds of millions of dollars over the years to pre… https://t.co/YsUdbuTHT3
# 9996  President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we shoul… https://t.co/2ewlaPQscF
# 9997                                                                 Wait til he hears how much climate change is gonna cost https://t.co/P6znQNsbLH
# 9998                                                                                                    Blue marble no more? https://t.co/hFLndZsiBB
#
#             original_tweet_link
# 0                           NaN
# 1       https://t.co/G0PqMIEUMV
# 2     [https://t.co/HWjCJGhQIx]
# 3     [https://t.co/2asxrk5Fqd]
# 4     [https://t.co/1J7lLUkYyY]
# ...                         ...
# 9994  [https://t.co/P1X5jfuUQC]
# 9995  [https://t.co/YsUdbuTHT3]
# 9996  [https://t.co/2ewlaPQscF]
# 9997  [https://t.co/P6znQNsbLH]
# 9998  [https://t.co/hFLndZsiBB]
#
# [9999 rows x 10 columns]

# %% [markdown]
# # Emoji detection
#
# See this example of emoji as unicode characters

# %%
climate_feed_df['text'].loc[3931]
# Out:
# ' Oh my god, CARBON.......😱😱😱 Cue the outrage machine against smartphone. These things are adding to climate change.'

# %% [markdown]
# We can use use regex to capture this emoji
#
# https://apps.timwhitlock.info/emoji/tables/unicode

# %%
emoji_regex = re.compile(r"\U0001F631", re.UNICODE)

# %%
emoji_regex.findall(climate_feed_df['text'].loc[3931])
# Out:
# ['😱', '😱', '😱']

# %% [markdown]
# We can use emoji and/or demoji libraries to make this task easier.  Feel free to use whatever approach you like here.
#
# Here is some documentation about unicode support in python
#
# https://docs.python.org/3/howto/unicode.html

# %%
! pip install emoji
# Out:
# Requirement already satisfied: emoji in /home/sfirestone/.local/lib/python3.8/site-packages (2.1.0)

# %%
! pip install demoji
# Out:
# Requirement already satisfied: demoji in /home/sfirestone/.local/lib/python3.8/site-packages (1.1.0)

# %%
import emoji
import demoji

# %% [markdown]
# # Q 8(2 points) Create a column  called *emoji*.  This column should contain a list of tuples for emoji detected in *text*. The first element of the tuple is the emoji detected and second is the text describing the emoji.

# %%
climate_feed_df["emoji"] = climate_feed_df['text'].apply(lambda x: list(demoji.findall(x).items()))
climate_feed_df["emoji"][3931]
# Out:
# [('😱', 'face screaming in fear')]
